# %%
list0 = ['aeiou', 50, False, 1/3, 0.96]
print(list0)

print(list0[2])
print(list0[0])
print(list0[-1])
print(list0[-2])
print(list0[0:2])
print(list0[2:])
print(list0[:2])
print(list0[-1:-3])
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:9: unexpected '['
# 1: list0 = [
#             ^
# Traceback:

# %%
print(c(1,2))
# Out:
# [1] 1 2
